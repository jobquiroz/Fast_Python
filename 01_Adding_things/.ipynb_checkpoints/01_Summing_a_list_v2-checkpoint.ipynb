# %% [markdown]
# ## Summing a list
#
# **Libraries**

# %%
import numpy as np
import random
import pandas as pd
from numba import jit
import matplotlib.pyplot as plt
from typing import Dict, List, Tuple, Any, NewType

# For code profiling
from utils.profiler import time_this, timed_report
from utils.profiler import ExponentialRange

# %%
def random_numeric_list_v2(n: int) -> List[float]:
    """This time using float (not float64) type"""
    return [random.random() for _ in range(n)]

# %% [markdown]
# All of the following algorithms run in O(n) time for a list of numbers with lenght n.

# %%
@time_this(lambda x: len(x))
def fast_sum(values: List[float]) -> float:
    accum = 0
    for value in values:
        accum += value
    return value

# %%
@time_this(lambda x: len(x))
def fast_native_sum(values: List[float]) -> float:
    return sum(values)

# %% [markdown]
# Despite the first one only using pure Python instructions, both of these functions have similar running times.

# %% [markdown]
# The following are vectorized implementations in numpy and pandas

# %%
@time_this(lambda x: len(x))
def numpy_fast_sum(values: np.ndarray) -> float:
    return np.sum(values)

# %%
@time_this(lambda x: len(x))
def pandas_fast_sum(values: pd.Series) -> float:
    return values.sum()

# %% [markdown]
# The pandas and numpy data structures typically have **strict typing requirements** that allow them to function with their compiled algorithms. For example, numpy needs to be sure that every single number in the `np.ndarray` is of type `np.float64`, or a similar numeric type, in order to perform operations on them. The custom types utilized by numpy and pandas are deliberately more specific than those in Python for this purpose.

# %% [markdown]
# The last summing function we will look at uses **numba** and will serve as a light introduction to numba.
#
# The `jit` decorator from `numba` allows us to perform just-in-time (JIT) compilation of Python functions. We specify the `nopython=True` argument to the decorator to force numba to not use any Python code to connect the dots when doing JIT compilation. This limits what we are allowed to do in the function in some respects, but that is not a problem here.
#
# Because the compilation occurs just-in-time rather than before the program is run, the compilation does not occur until the first time the function is actually used within the script. Therefore, for the purposes of profiling our code, we make sure to run a non-trivial computation at the module level before wrapping it in another caller.
#
# Notice that the `numba_fast_sum` definition looks exactly like the pure Python summing function, save for the type hint in the input argument. The numba library integrates closely with numpy and benefits from the strong typing supplied by numpy, so we will try to pass `np.ndarray` objects into numba functions whenever we can.

# %%
@jit(nopython = True)
def _numba_fast_sum(values: np.ndarray) -> float:
    """
    JIT compilation occurs after one use
    """
    accum = 0
    for value in values:
        accum += value
    return accum

# Force numba to run jit compilation
_numba_fast_sum(np.random.random(100000))

@time_this(lambda x: len(x))
def numba_fast_sum(values: np.ndarray) -> float:
    """
    Redeclare optimized wrapper
    """
    return _numba_fast_sum(values)

# %% [markdown]
# #### Profiling:

# %%
exp_range = ExponentialRange(0, 8, 1/4)
values = random_numeric_list_v2(exp_range.max)

with timed_report():
    for i in exp_range.iterator():
        fast_sum(values[:i])

    for i in exp_range.iterator():
        fast_native_sum(values[:i])

    for i in exp_range.iterator():
        numpy_fast_sum(np.array(values[:i]))

    for i in exp_range.iterator():
        pandas_fast_sum(pd.Series(values[:i]))

    for i in exp_range.iterator():
        numba_fast_sum(np.array(values[:i]))
# Out:
# fast_sum
#     n   = 1 values
#     t   = 0.001 ms
#     n/t = 666.6667 values per ms
#
# fast_sum
#     n   = 3 values
#     t   = 0.001 ms
#     n/t = 2500.0 values per ms
#
# fast_sum
#     n   = 5 values
#     t   = 0.001 ms
#     n/t = 5555.5555 values per ms
#
# fast_sum
#     n   = 10 values
#     t   = 0.001 ms
#     n/t = 11111.1111 values per ms
#
# fast_sum
#     n   = 17 values
#     t   = 0.001 ms
#     n/t = 17000.0 values per ms
#
# fast_sum
#     n   = 31 values
#     t   = 0.002 ms
#     n/t = 19375.0001 values per ms
#
# fast_sum
#     n   = 56 values
#     t   = 0.003 ms
#     n/t = 17500.0001 values per ms
#
# fast_sum
#     n   = 100 values
#     t   = 0.004 ms
#     n/t = 24390.2438 values per ms
#
# fast_sum
#     n   = 177 values
#     t   = 0.007 ms
#     n/t = 26818.1818 values per ms
#
# fast_sum
#     n   = 316 values
#     t   = 0.011 ms
#     n/t = 27964.6017 values per ms
#
# fast_sum
#     n   = 562 values
#     t   = 0.033 ms
#     n/t = 16978.852 values per ms
#
# fast_sum
#     n   = 1000 values
#     t   = 0.047 ms
#     n/t = 21141.649 values per ms
#
# fast_sum
#     n   = 1778 values
#     t   = 0.157 ms
#     n/t = 11310.4326 values per ms
#
# fast_sum
#     n   = 3162 values
#     t   = 0.127 ms
#     n/t = 24878.0488 values per ms
#
# fast_sum
#     n   = 5623 values
#     t   = 0.212 ms
#     n/t = 26498.5862 values per ms
#
# fast_sum
#     n   = 10000 values
#     t   = 0.364 ms
#     n/t = 27502.7503 values per ms
#
# fast_sum
#     n   = 17782 values
#     t   = 0.624 ms
#     n/t = 28478.5394 values per ms
#
# fast_sum
#     n   = 31622 values
#     t   = 1.07 ms
#     n/t = 29558.796 values per ms
#
# fast_sum
#     n   = 56234 values
#     t   = 1.883 ms
#     n/t = 29868.8054 values per ms
#
# fast_sum
#     n   = 100000 values
#     t   = 3.576 ms
#     n/t = 27964.2058 values per ms
#
# fast_sum
#     n   = 177827 values
#     t   = 7.587 ms
#     n/t = 23437.7636 values per ms
#
# fast_sum
#     n   = 316227 values
#     t   = 13.638 ms
#     n/t = 23187.0275 values per ms
#
# fast_sum
#     n   = 562341 values
#     t   = 31.027 ms
#     n/t = 18124.4219 values per ms
#
# fast_sum
#     n   = 1000000 values
#     t   = 36.648 ms
#     n/t = 27286.6931 values per ms
#
# fast_sum
#     n   = 1778279 values
#     t   = 77.191 ms
#     n/t = 23037.2386 values per ms
#
# fast_sum
#     n   = 3162277 values
#     t   = 170.34 ms
#     n/t = 18564.4786 values per ms
#
# fast_sum
#     n   = 5623413 values
#     t   = 347.829 ms
#     n/t = 16167.177 values per ms
#
# fast_sum
#     n   = 10000000 values
#     t   = 462.91 ms
#     n/t = 21602.476 values per ms
#
# fast_sum
#     n   = 17782794 values
#     t   = 681.504 ms
#     n/t = 26093.4627 values per ms
#
# fast_sum
#     n   = 31622776 values
#     t   = 1206.868 ms
#     n/t = 26202.342 values per ms
#
# fast_sum
#     n   = 56234132 values
#     t   = 2557.926 ms
#     n/t = 21984.2711 values per ms
#
# fast_sum
#     n   = 100000000 values
#     t   = 4533.239 ms
#     n/t = 22059.2801 values per ms
#
# fast_native_sum
#     n   = 1 values
#     t   = 0.003 ms
#     n/t = 312.5 values per ms
#
# fast_native_sum
#     n   = 3 values
#     t   = 0.001 ms
#     n/t = 3333.3333 values per ms
#
# fast_native_sum
#     n   = 5 values
#     t   = 0.001 ms
#     n/t = 7142.857 values per ms
#
# fast_native_sum
#     n   = 10 values
#     t   = 0.001 ms
#     n/t = 16666.6669 values per ms
#
# fast_native_sum
#     n   = 17 values
#     t   = 0.003 ms
#     n/t = 5666.6666 values per ms
#
# fast_native_sum
#     n   = 31 values
#     t   = 0.003 ms
#     n/t = 10333.3334 values per ms
#
# fast_native_sum
#     n   = 56 values
#     t   = 0.002 ms
#     n/t = 28000.0001 values per ms
#
# fast_native_sum
#     n   = 100 values
#     t   = 0.001 ms
#     n/t = 90909.0893 values per ms
#
# fast_native_sum
#     n   = 177 values
#     t   = 0.001 ms
#     n/t = 136153.8483 values per ms
#
# fast_native_sum
#     n   = 316 values
#     t   = 0.016 ms
#     n/t = 20127.3885 values per ms
#
# fast_native_sum
#     n   = 562 values
#     t   = 0.003 ms
#     n/t = 193793.1036 values per ms
#
# fast_native_sum
#     n   = 1000 values
#     t   = 0.005 ms
#     n/t = 222222.2214 values per ms
#
# fast_native_sum
#     n   = 1778 values
#     t   = 0.021 ms
#     n/t = 86731.7073 values per ms
#
# fast_native_sum
#     n   = 3162 values
#     t   = 0.013 ms
#     n/t = 245116.279 values per ms
#
# fast_native_sum
#     n   = 5623 values
#     t   = 0.029 ms
#     n/t = 193230.2405 values per ms
#
# fast_native_sum
#     n   = 10000 values
#     t   = 0.038 ms
#     n/t = 261780.1049 values per ms
#
# fast_native_sum
#     n   = 17782 values
#     t   = 0.065 ms
#     n/t = 275689.9224 values per ms
#
# fast_native_sum
#     n   = 31622 values
#     t   = 0.124 ms
#     n/t = 255634.5998 values per ms
#
# fast_native_sum
#     n   = 56234 values
#     t   = 0.231 ms
#     n/t = 243859.497 values per ms
#
# fast_native_sum
#     n   = 100000 values
#     t   = 0.586 ms
#     n/t = 170735.8716 values per ms
#
# fast_native_sum
#     n   = 177827 values
#     t   = 1.133 ms
#     n/t = 156910.7915 values per ms
#
# fast_native_sum
#     n   = 316227 values
#     t   = 2.842 ms
#     n/t = 111269.1766 values per ms
#
# fast_native_sum
#     n   = 562341 values
#     t   = 4.88 ms
#     n/t = 115224.3669 values per ms
#
# fast_native_sum
#     n   = 1000000 values
#     t   = 8.182 ms
#     n/t = 122225.4816 values per ms
#
# fast_native_sum
#     n   = 1778279 values
#     t   = 14.386 ms
#     n/t = 123609.1976 values per ms
#
# fast_native_sum
#     n   = 3162277 values
#     t   = 24.407 ms
#     n/t = 129565.408 values per ms
#
# fast_native_sum
#     n   = 5623413 values
#     t   = 28.494 ms
#     n/t = 197355.6704 values per ms
#
# fast_native_sum
#     n   = 10000000 values
#     t   = 50.733 ms
#     n/t = 197110.3621 values per ms
#
# fast_native_sum
#     n   = 17782794 values
#     t   = 88.821 ms
#     n/t = 200209.3424 values per ms
#
# fast_native_sum
#     n   = 31622776 values
#     t   = 183.27 ms
#     n/t = 172547.7588 values per ms
#
# fast_native_sum
#     n   = 56234132 values
#     t   = 427.693 ms
#     n/t = 131482.3469 values per ms
#
# fast_native_sum
#     n   = 100000000 values
#     t   = 588.203 ms
#     n/t = 170009.3335 values per ms
#
# numpy_fast_sum
#     n   = 1 values
#     t   = 0.115 ms
#     n/t = 8.7032 values per ms
#
# numpy_fast_sum
#     n   = 3 values
#     t   = 0.027 ms
#     n/t = 109.4891 values per ms
#
# numpy_fast_sum
#     n   = 5 values
#     t   = 0.017 ms
#     n/t = 290.6977 values per ms
#
# numpy_fast_sum
#     n   = 10 values
#     t   = 0.012 ms
#     n/t = 840.3361 values per ms
#
# numpy_fast_sum
#     n   = 17 values
#     t   = 0.036 ms
#     n/t = 477.5281 values per ms
#
# numpy_fast_sum
#     n   = 31 values
#     t   = 0.049 ms
#     n/t = 627.5304 values per ms
#
# numpy_fast_sum
#     n   = 56 values
#     t   = 0.018 ms
#     n/t = 3128.4916 values per ms
#
# numpy_fast_sum
#     n   = 100 values
#     t   = 0.022 ms
#     n/t = 4504.5045 values per ms
#
# numpy_fast_sum
#     n   = 177 values
#     t   = 0.034 ms
#     n/t = 5175.4386 values per ms
#
# numpy_fast_sum
#     n   = 316 values
#     t   = 0.028 ms
#     n/t = 11285.7143 values per ms
#
# numpy_fast_sum
#     n   = 562 values
#     t   = 0.011 ms
#     n/t = 49734.5132 values per ms
#
# numpy_fast_sum
#     n   = 1000 values
#     t   = 0.014 ms
#     n/t = 70921.9859 values per ms
#
# numpy_fast_sum
#     n   = 1778 values
#     t   = 0.032 ms
#     n/t = 56265.8228 values per ms
#
# numpy_fast_sum
#     n   = 3162 values
#     t   = 0.011 ms
#     n/t = 295514.019 values per ms
#
# numpy_fast_sum
#     n   = 5623 values
#     t   = 0.038 ms
#     n/t = 146814.6214 values per ms
#
# numpy_fast_sum
#     n   = 10000 values
#     t   = 0.021 ms
#     n/t = 469483.5678 values per ms
#
# numpy_fast_sum
#     n   = 17782 values
#     t   = 0.431 ms
#     n/t = 41228.843 values per ms
#
# numpy_fast_sum
#     n   = 31622 values
#     t   = 0.464 ms
#     n/t = 68194.9536 values per ms
#
# numpy_fast_sum
#     n   = 56234 values
#     t   = 0.14 ms
#     n/t = 401958.5418 values per ms
#
# numpy_fast_sum
#     n   = 100000 values
#     t   = 0.711 ms
#     n/t = 140567.8943 values per ms
#
# numpy_fast_sum
#     n   = 177827 values
#     t   = 0.38 ms
#     n/t = 468088.9708 values per ms
#
# numpy_fast_sum
#     n   = 316227 values
#     t   = 0.62 ms
#     n/t = 509879.0713 values per ms
#
# numpy_fast_sum
#     n   = 562341 values
#     t   = 0.752 ms
#     n/t = 747595.0545 values per ms
#
# numpy_fast_sum
#     n   = 1000000 values
#     t   = 1.287 ms
#     n/t = 776880.0497 values per ms
#
# numpy_fast_sum
#     n   = 1778279 values
#     t   = 2.848 ms
#     n/t = 624395.7163 values per ms
#
# numpy_fast_sum
#     n   = 3162277 values
#     t   = 4.801 ms
#     n/t = 658629.3296 values per ms
#
# numpy_fast_sum
#     n   = 5623413 values
#     t   = 8.86 ms
#     n/t = 634675.2367 values per ms
# numpy_fast_sum
#     n   = 10000000 values
#     t   = 15.686 ms
#     n/t = 637494.9 values per ms
#
# numpy_fast_sum
#     n   = 17782794 values
#     t   = 24.538 ms
#     n/t = 724710.2022 values per ms
#
# numpy_fast_sum
#     n   = 31622776 values
#     t   = 55.7 ms
#     n/t = 567737.9371 values per ms
#
# numpy_fast_sum
#     n   = 56234132 values
#     t   = 73.556 ms
#     n/t = 764503.5918 values per ms
#
# numpy_fast_sum
#     n   = 100000000 values
#     t   = 161.953 ms
#     n/t = 617464.6162 values per ms
#
# pandas_fast_sum
#     n   = 1 values
#     t   = 0.273 ms
#     n/t = 3.6617 values per ms
#
# pandas_fast_sum
#     n   = 3 values
#     t   = 0.139 ms
#     n/t = 21.5363 values per ms
#
# pandas_fast_sum
#     n   = 5 values
#     t   = 0.126 ms
#     n/t = 39.557 values per ms
#
# pandas_fast_sum
#     n   = 10 values
#     t   = 0.111 ms
#     n/t = 90.0901 values per ms
#
# pandas_fast_sum
#     n   = 17 values
#     t   = 0.139 ms
#     n/t = 122.5667 values per ms
#
# pandas_fast_sum
#     n   = 31 values
#     t   = 0.13 ms
#     n/t = 238.4615 values per ms
#
# pandas_fast_sum
#     n   = 56 values
#     t   = 0.13 ms
#     n/t = 430.4381 values per ms
#
# pandas_fast_sum
#     n   = 100 values
#     t   = 0.125 ms
#     n/t = 803.2129 values per ms
#
# pandas_fast_sum
#     n   = 177 values
#     t   = 0.127 ms
#     n/t = 1391.5094 values per ms
#
# pandas_fast_sum
#     n   = 316 values
#     t   = 0.143 ms
#     n/t = 2205.164 values per ms
#
# pandas_fast_sum
#     n   = 562 values
#     t   = 1.054 ms
#     n/t = 533.1562 values per ms
#
# pandas_fast_sum
#     n   = 1000 values
#     t   = 0.148 ms
#     n/t = 6743.0883 values per ms
#
# pandas_fast_sum
#     n   = 1778 values
#     t   = 0.811 ms
#     n/t = 2191.8146 values per ms
#
# pandas_fast_sum
#     n   = 3162 values
#     t   = 0.284 ms
#     n/t = 11118.1435 values per ms
#
# pandas_fast_sum
#     n   = 5623 values
#     t   = 0.118 ms
#     n/t = 47451.4768 values per ms
#
# pandas_fast_sum
#     n   = 10000 values
#     t   = 0.81 ms
#     n/t = 12350.2532 values per ms
#
# pandas_fast_sum
#     n   = 17782 values
#     t   = 0.537 ms
#     n/t = 33119.7616 values per ms
#
# pandas_fast_sum
#     n   = 31622 values
#     t   = 0.222 ms
#     n/t = 142762.9797 values per ms
#
# pandas_fast_sum
#     n   = 56234 values
#     t   = 0.499 ms
#     n/t = 112715.9751 values per ms
#
# pandas_fast_sum
#     n   = 100000 values
#     t   = 1.008 ms
#     n/t = 99196.5083 values per ms
#
# pandas_fast_sum
#     n   = 177827 values
#     t   = 1.486 ms
#     n/t = 119692.4009 values per ms
#
# pandas_fast_sum
#     n   = 316227 values
#     t   = 2.634 ms
#     n/t = 120037.5797 values per ms
#
# pandas_fast_sum
#     n   = 562341 values
#     t   = 3.582 ms
#     n/t = 156977.6401 values per ms
#
# pandas_fast_sum
#     n   = 1000000 values
#     t   = 6.924 ms
#     n/t = 144418.9304 values per ms
#
# pandas_fast_sum
#     n   = 1778279 values
#     t   = 11.632 ms
#     n/t = 152876.8666 values per ms
#
# pandas_fast_sum
#     n   = 3162277 values
#     t   = 26.227 ms
#     n/t = 120573.8002 values per ms
#
# pandas_fast_sum
#     n   = 5623413 values
#     t   = 41.694 ms
#     n/t = 134874.082 values per ms
#
# pandas_fast_sum
#     n   = 10000000 values
#     t   = 77.475 ms
#     n/t = 129074.3946 values per ms
#
# pandas_fast_sum
#     n   = 17782794 values
#     t   = 138.459 ms
#     n/t = 128434.1084 values per ms
#
# pandas_fast_sum
#     n   = 31622776 values
#     t   = 249.613 ms
#     n/t = 126687.0635 values per ms
#
# pandas_fast_sum
#     n   = 56234132 values
#     t   = 420.482 ms
#     n/t = 133737.2474 values per ms
