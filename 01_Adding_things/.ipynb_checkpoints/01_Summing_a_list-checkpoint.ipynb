# %% [markdown]
# ## Summing a list
#
# **Libraries**

# %%
import numpy as np
import pandas as pd
from numba import jit
import matplotlib.pyplot as plt
from typing import Dict, List, Tuple, Any, NewType

# For code profiling
from utils.profiler import time_this, timed_report
from utils.profiler import ExponentialRange

# %%
def random_numeric_list(n: int) -> List[np.float64]:
    return list(np.random.random(n))

# %% [markdown]
# All of the following algorithms run in O(n) time for a list of numbers with lenght n.

# %%
@time_this (lambda x: len(x))
def fast_sum(values: List[float]) -> float:
    accum = 0
    for value in values:
        accum += value
    return value

# %%
@time_this(lambda x: len(x))
def fast_native_sum(values: List[float]) -> float:
    return sum(values)

# %% [markdown]
# Despite the first one only using pure Python instructions, both of these functions have similar running times.

# %% [markdown]
# The following are vectorized implementations in numpy and pandas

# %%
@time_this(lambda x: len(x))
def numpy_fast_sum(values: np.ndarray) -> float:
    return np.sum(values)

# %%
@time_this(lambda x: len(x))
def pandas_fast_sum(values: pd.Series) -> float:
    return values.sum()

# %% [markdown]
# The pandas and numpy data structures typically have **strict typing requirements** that allow them to function with their compiled algorithms. For example, numpy needs to be sure that every single number in the `np.ndarray` is of type `np.float64`, or a similar numeric type, in order to perform operations on them. The custom types utilized by numpy and pandas are deliberately more specific than those in Python for this purpose.

# %% [markdown]
# The last summing function we will look at uses **numba** and will serve as a light introduction to numba.
#
# The `jit` decorator from `numba` allows us to perform just-in-time (JIT) compilation of Python functions. We specify the `nopython=True` argument to the decorator to force numba to not use any Python code to connect the dots when doing JIT compilation. This limits what we are allowed to do in the function in some respects, but that is not a problem here.
#
# Because the compilation occurs just-in-time rather than before the program is run, the compilation does not occur until the first time the function is actually used within the script. Therefore, for the purposes of profiling our code, we make sure to run a non-trivial computation at the module level before wrapping it in another caller.
#
# Notice that the `numba_fast_sum` definition looks exactly like the pure Python summing function, save for the type hint in the input argument. The numba library integrates closely with numpy and benefits from the strong typing supplied by numpy, so we will try to pass `np.ndarray` objects into numba functions whenever we can.

# %%
@jit(nopython = True)
def _numba_fast_sum(values: np.ndarray) -> float:
    """
    JIT compilation occurs after one use
    """
    accum = 0
    for value in values:
        accum += value
    return accum

# Force numba to run jit compilation
_numba_fast_sum(np.random.random(100000))

@time_this (lambda x: len(x))
def numba_fast_sum(values: np.ndarray) -> float:
    """
    Redeclare optimized wrapper
    """
    return _numba_fast_sum(values)

# %% [markdown]
# #### Profiling:

# %%
exp_range = ExponentialRange(0, 7, 1/4)
values = random_numeric_list(exp_range.max)

with timed_report():
    for i in exp_range.iterator():
        fast_sum(values[:i])

    for i in exp_range.iterator():
        fast_native_sum(values[:i])

    for i in exp_range.iterator():
        numpy_fast_sum(np.array(values[:i]))

    for i in exp_range.iterator():
        pandas_fast_sum(pd.Series(values[:i]))

    for i in exp_range.iterator():
        numba_fast_sum(np.array(values[:i]))
# Out:
# fast_sum
#     n   = 1 values
#     t   = 0.046 ms
#     n/t = 21.692 values per ms
#
# fast_sum
#     n   = 3 values
#     t   = 0.006 ms
#     n/t = 476.1905 values per ms
#
# fast_sum
#     n   = 5 values
#     t   = 0.004 ms
#     n/t = 1282.0513 values per ms
#
# fast_sum
#     n   = 10 values
#     t   = 0.005 ms
#     n/t = 2173.913 values per ms
#
# fast_sum
#     n   = 17 values
#     t   = 0.005 ms
#     n/t = 3207.5472 values per ms
#
# fast_sum
#     n   = 31 values
#     t   = 0.008 ms
#     n/t = 3974.359 values per ms
#
# fast_sum
#     n   = 56 values
#     t   = 0.01 ms
#     n/t = 5600.0 values per ms
#
# fast_sum
#     n   = 100 values
#     t   = 0.036 ms
#     n/t = 2747.2527 values per ms
#
# fast_sum
#     n   = 177 values
#     t   = 0.025 ms
#     n/t = 7137.0968 values per ms
#
# fast_sum
#     n   = 316 values
#     t   = 0.057 ms
#     n/t = 5553.6028 values per ms
#
# fast_sum
#     n   = 562 values
#     t   = 0.103 ms
#     n/t = 5461.6132 values per ms
#
# fast_sum
#     n   = 1000 values
#     t   = 0.152 ms
#     n/t = 6591.9578 values per ms
#
# fast_sum
#     n   = 1778 values
#     t   = 0.239 ms
#     n/t = 7426.9006 values per ms
#
# fast_sum
#     n   = 3162 values
#     t   = 0.396 ms
#     n/t = 7978.8039 values per ms
#
# fast_sum
#     n   = 5623 values
#     t   = 0.674 ms
#     n/t = 8343.9679 values per ms
#
# fast_sum
#     n   = 10000 values
#     t   = 1.163 ms
#     n/t = 8598.4523 values per ms
#
# fast_sum
#     n   = 17782 values
#     t   = 2.074 ms
#     n/t = 8571.704 values per ms
#
# fast_sum
#     n   = 31622 values
#     t   = 3.89 ms
#     n/t = 8129.8848 values per ms
#
# fast_sum
#     n   = 56234 values
#     t   = 6.872 ms
#     n/t = 8182.9426 values per ms
#
# fast_sum
#     n   = 100000 values
#     t   = 12.919 ms
#     n/t = 7740.657 values per ms
#
# fast_sum
#     n   = 177827 values
#     t   = 23.869 ms
#     n/t = 7450.1236 values per ms
#
# fast_sum
#     n   = 316227 values
#     t   = 42.155 ms
#     n/t = 7501.4945 values per ms
#
# fast_sum
#     n   = 562341 values
#     t   = 75.307 ms
#     n/t = 7467.2741 values per ms
#
# fast_sum
#     n   = 1000000 values
#     t   = 147.737 ms
#     n/t = 6768.7622 values per ms
#
# fast_sum
#     n   = 1778279 values
#     t   = 253.709 ms
#     n/t = 7009.1203 values per ms
#
# fast_sum
#     n   = 3162277 values
#     t   = 443.358 ms
#     n/t = 7132.5572 values per ms
#
# fast_sum
#     n   = 5623413 values
#     t   = 1036.672 ms
#     n/t = 5424.4883 values per ms
#
# fast_sum
#     n   = 10000000 values
#     t   = 1451.183 ms
#     n/t = 6890.9306 values per ms
#
# fast_native_sum
#     n   = 1 values
#     t   = 0.036 ms
#     n/t = 27.8552 values per ms
#
# fast_native_sum
#     n   = 3 values
#     t   = 0.007 ms
#     n/t = 434.7826 values per ms
#
# fast_native_sum
#     n   = 5 values
#     t   = 0.004 ms
#     n/t = 1219.5122 values per ms
#
# fast_native_sum
#     n   = 10 values
#     t   = 0.005 ms
#     n/t = 2222.2222 values per ms
#
# fast_native_sum
#     n   = 17 values
#     t   = 0.003 ms
#     n/t = 5483.871 values per ms
#
# fast_native_sum
#     n   = 31 values
#     t   = 0.004 ms
#     n/t = 7750.0 values per ms
#
# fast_native_sum
#     n   = 56 values
#     t   = 0.006 ms
#     n/t = 10000.0 values per ms
#
# fast_native_sum
#     n   = 100 values
#     t   = 0.011 ms
#     n/t = 9090.9091 values per ms
#
# fast_native_sum
#     n   = 177 values
#     t   = 0.016 ms
#     n/t = 10925.9259 values per ms
#
# fast_native_sum
#     n   = 316 values
#     t   = 0.026 ms
#     n/t = 11969.697 values per ms
#
# fast_native_sum
#     n   = 562 values
#     t   = 0.055 ms
#     n/t = 10236.7942 values per ms
#
# fast_native_sum
#     n   = 1000 values
#     t   = 0.097 ms
#     n/t = 10319.9174 values per ms
#
# fast_native_sum
#     n   = 1778 values
#     t   = 0.198 ms
#     n/t = 8979.798 values per ms
#
# fast_native_sum
#     n   = 3162 values
#     t   = 0.325 ms
#     n/t = 9726.2381 values per ms
#
# fast_native_sum
#     n   = 5623 values
#     t   = 0.506 ms
#     n/t = 11119.2407 values per ms
#
# fast_native_sum
#     n   = 10000 values
#     t   = 0.715 ms
#     n/t = 13991.8847 values per ms
#
# fast_native_sum
#     n   = 17782 values
#     t   = 1.261 ms
#     n/t = 14099.2705 values per ms
#
# fast_native_sum
#     n   = 31622 values
#     t   = 2.292 ms
#     n/t = 13797.2861 values per ms
#
# fast_native_sum
#     n   = 56234 values
#     t   = 4.015 ms
#     n/t = 14004.2336 values per ms
#
# fast_native_sum
#     n   = 100000 values
#     t   = 8.122 ms
#     n/t = 12312.39 values per ms
#
# fast_native_sum
#     n   = 177827 values
#     t   = 16.216 ms
#     n/t = 10966.2798 values per ms
#
# fast_native_sum
#     n   = 316227 values
#     t   = 26.87 ms
#     n/t = 11768.6442 values per ms
#
# fast_native_sum
#     n   = 562341 values
#     t   = 44.063 ms
#     n/t = 12762.262 values per ms
#
# fast_native_sum
#     n   = 1000000 values
#     t   = 88.575 ms
#     n/t = 11289.8291 values per ms
#
# fast_native_sum
#     n   = 1778279 values
#     t   = 142.47 ms
#     n/t = 12481.7348 values per ms
#
# fast_native_sum
#     n   = 3162277 values
#     t   = 276.245 ms
#     n/t = 11447.3803 values per ms
#
# fast_native_sum
#     n   = 5623413 values
#     t   = 450.48 ms
#     n/t = 12483.1469 values per ms
#
# fast_native_sum
#     n   = 10000000 values
#     t   = 908.559 ms
#     n/t = 11006.4399 values per ms
#
# numpy_fast_sum
#     n   = 1 values
#     t   = 0.083 ms
#     n/t = 12.0627 values per ms
#
# numpy_fast_sum
#     n   = 3 values
#     t   = 0.026 ms
#     n/t = 116.2791 values per ms
#
# numpy_fast_sum
#     n   = 5 values
#     t   = 0.015 ms
#     n/t = 333.3333 values per ms
#
# numpy_fast_sum
#     n   = 10 values
#     t   = 0.016 ms
#     n/t = 641.0256 values per ms
#
# numpy_fast_sum
#     n   = 17 values
#     t   = 0.017 ms
#     n/t = 977.0115 values per ms
#
# numpy_fast_sum
#     n   = 31 values
#     t   = 0.011 ms
#     n/t = 2743.3628 values per ms
#
# numpy_fast_sum
#     n   = 56 values
#     t   = 0.015 ms
#     n/t = 3783.7838 values per ms
#
# numpy_fast_sum
#     n   = 100 values
#     t   = 0.022 ms
#     n/t = 4608.2949 values per ms
#
# numpy_fast_sum
#     n   = 177 values
#     t   = 0.033 ms
#     n/t = 5429.4479 values per ms
#
# numpy_fast_sum
#     n   = 316 values
#     t   = 0.008 ms
#     n/t = 42133.3333 values per ms
#
# numpy_fast_sum
#     n   = 562 values
#     t   = 0.017 ms
#     n/t = 33652.6946 values per ms
#
# numpy_fast_sum
#     n   = 1000 values
#     t   = 0.013 ms
#     n/t = 74626.8657 values per ms
#
# numpy_fast_sum
#     n   = 1778 values
#     t   = 0.01 ms
#     n/t = 177800.0 values per ms
#
# numpy_fast_sum
#     n   = 3162 values
#     t   = 0.016 ms
#     n/t = 196397.5155 values per ms
#
# numpy_fast_sum
#     n   = 5623 values
#     t   = 0.031 ms
#     n/t = 182564.9351 values per ms
#
# numpy_fast_sum
#     n   = 10000 values
#     t   = 0.032 ms
#     n/t = 309597.5232 values per ms
#
# numpy_fast_sum
#     n   = 17782 values
#     t   = 0.423 ms
#     n/t = 42027.8894 values per ms
#
# numpy_fast_sum
#     n   = 31622 values
#     t   = 0.194 ms
#     n/t = 162748.3273 values per ms
#
# numpy_fast_sum
#     n   = 56234 values
#     t   = 0.585 ms
#     n/t = 96159.3707 values per ms
#
# numpy_fast_sum
#     n   = 100000 values
#     t   = 1.18 ms
#     n/t = 84745.7627 values per ms
#
# numpy_fast_sum
#     n   = 177827 values
#     t   = 0.41 ms
#     n/t = 434041.9819 values per ms
#
# numpy_fast_sum
#     n   = 316227 values
#     t   = 0.826 ms
#     n/t = 382748.7291 values per ms
#
# numpy_fast_sum
#     n   = 562341 values
#     t   = 0.974 ms
#     n/t = 577411.4385 values per ms
#
# numpy_fast_sum
#     n   = 1000000 values
#     t   = 2.012 ms
#     n/t = 497017.8926 values per ms
#
# numpy_fast_sum
#     n   = 1778279 values
#     t   = 3.892 ms
#     n/t = 456953.1812 values per ms
#
# numpy_fast_sum
#     n   = 3162277 values
#     t   = 6.491 ms
#     n/t = 487156.1937 values per ms
#
# numpy_fast_sum
#     n   = 5623413 values
#     t   = 9.852 ms
#     n/t = 570800.5644 values per ms
#
# numpy_fast_sum
#     n   = 10000000 values
#     t   = 17.227 ms
#     n/t = 580470.6456 values per ms
#
# pandas_fast_sum
#     n   = 1 values
#     t   = 0.296 ms
#     n/t = 3.3829 values per ms
#
# pandas_fast_sum
#     n   = 3 values
#     t   = 0.159 ms
#     n/t = 18.9036 values per ms
#
# pandas_fast_sum
#     n   = 5 values
#     t   = 0.15 ms
#     n/t = 33.2447 values per ms
#
# pandas_fast_sum
#     n   = 10 values
#     t   = 0.118 ms
#     n/t = 84.9618 values per ms
#
# pandas_fast_sum
#     n   = 17 values
#     t   = 0.198 ms
#     n/t = 85.6855 values per ms
#
# pandas_fast_sum
#     n   = 31 values
#     t   = 0.21 ms
#     n/t = 147.2684 values per ms
#
# pandas_fast_sum
#     n   = 56 values
#     t   = 0.139 ms
#     n/t = 401.7217 values per ms
#
# pandas_fast_sum
#     n   = 100 values
#     t   = 0.167 ms
#     n/t = 599.5204 values per ms
#
# pandas_fast_sum
#     n   = 177 values
#     t   = 0.216 ms
#     n/t = 820.9647 values per ms
#
# pandas_fast_sum
#     n   = 316 values
#     t   = 0.11 ms
#     n/t = 2877.9599 values per ms
#
# pandas_fast_sum
#     n   = 562 values
#     t   = 0.111 ms
#     n/t = 5053.9568 values per ms
#
# pandas_fast_sum
#     n   = 1000 values
#     t   = 0.333 ms
#     n/t = 3001.2005 values per ms
#
# pandas_fast_sum
#     n   = 1778 values
#     t   = 0.206 ms
#     n/t = 8639.4558 values per ms
#
# pandas_fast_sum
#     n   = 3162 values
#     t   = 0.136 ms
#     n/t = 23267.1082 values per ms
#
# pandas_fast_sum
#     n   = 5623 values
#     t   = 2.447 ms
#     n/t = 2297.6341 values per ms
#
# pandas_fast_sum
#     n   = 10000 values
#     t   = 0.164 ms
#     n/t = 61124.6944 values per ms
#
# pandas_fast_sum
#     n   = 17782 values
#     t   = 0.694 ms
#     n/t = 25604.0317 values per ms
#
# pandas_fast_sum
#     n   = 31622 values
#     t   = 0.801 ms
#     n/t = 39463.372 values per ms
#
# pandas_fast_sum
#     n   = 56234 values
#     t   = 0.603 ms
#     n/t = 93241.5851 values per ms
#
# pandas_fast_sum
#     n   = 100000 values
#     t   = 1.649 ms
#     n/t = 60624.4316 values per ms
#
# pandas_fast_sum
#     n   = 177827 values
#     t   = 1.862 ms
#     n/t = 95487.8376 values per ms
#
# pandas_fast_sum
#     n   = 316227 values
#     t   = 3.689 ms
#     n/t = 85733.2249 values per ms
# pandas_fast_sum
#     n   = 562341 values
#     t   = 4.626 ms
#     n/t = 121558.3321 values per ms
#
# pandas_fast_sum
#     n   = 1000000 values
#     t   = 10.804 ms
#     n/t = 92554.0284 values per ms
#
# pandas_fast_sum
#     n   = 1778279 values
#     t   = 12.668 ms
#     n/t = 140375.671 values per ms
#
# pandas_fast_sum
#     n   = 3162277 values
#     t   = 22.151 ms
#     n/t = 142758.7219 values per ms
#
# pandas_fast_sum
#     n   = 5623413 values
#     t   = 56.488 ms
#     n/t = 99550.0484 values per ms
#
# pandas_fast_sum
#     n   = 10000000 values
#     t   = 68.031 ms
#     n/t = 146991.3804 values per ms
#
# numba_fast_sum
#     n   = 1 values
#     t   = 0.035 ms
#     n/t = 28.6533 values per ms
#
# numba_fast_sum
#     n   = 3 values
#     t   = 0.031 ms
#     n/t = 98.0392 values per ms
#
# numba_fast_sum
#     n   = 5 values
#     t   = 0.027 ms
#     n/t = 187.9699 values per ms
#
# numba_fast_sum
#     n   = 10 values
#     t   = 0.01 ms
#     n/t = 970.8738 values per ms
#
# numba_fast_sum
#     n   = 17 values
#     t   = 0.017 ms
#     n/t = 1017.9641 values per ms
#
# numba_fast_sum
#     n   = 31 values
#     t   = 0.003 ms
#     n/t = 9393.9394 values per ms
#
# numba_fast_sum
#     n   = 56 values
#     t   = 0.016 ms
#     n/t = 3478.2609 values per ms
#
# numba_fast_sum
#     n   = 100 values
#     t   = 0.004 ms
#     n/t = 25641.0256 values per ms
#
# numba_fast_sum
#     n   = 177 values
#     t   = 0.004 ms
#     n/t = 42142.8571 values per ms
#
# numba_fast_sum
#     n   = 316 values
#     t   = 0.001 ms
#     n/t = 210666.6667 values per ms
#
# numba_fast_sum
#     n   = 562 values
#     t   = 0.002 ms
#     n/t = 312222.2223 values per ms
#
# numba_fast_sum
#     n   = 1000 values
#     t   = 0.002 ms
#     n/t = 454545.4544 values per ms
#
# numba_fast_sum
#     n   = 1778 values
#     t   = 0.005 ms
#     n/t = 348627.451 values per ms
#
# numba_fast_sum
#     n   = 3162 values
#     t   = 0.005 ms
#     n/t = 632400.0002 values per ms
#
# numba_fast_sum
#     n   = 5623 values
#     t   = 0.009 ms
#     n/t = 624777.7779 values per ms
#
# numba_fast_sum
#     n   = 10000 values
#     t   = 0.014 ms
#     n/t = 714285.7143 values per ms
#
# numba_fast_sum
#     n   = 17782 values
#     t   = 0.022 ms
#     n/t = 819447.0046 values per ms
#
# numba_fast_sum
#     n   = 31622 values
#     t   = 0.038 ms
#     n/t = 834353.562 values per ms
#
# numba_fast_sum
#     n   = 56234 values
#     t   = 0.073 ms
#     n/t = 773507.5653 values per ms
#
# numba_fast_sum
#     n   = 100000 values
#     t   = 0.122 ms
#     n/t = 821018.0624 values per ms
#
# numba_fast_sum
#     n   = 177827 values
#     t   = 0.238 ms
#     n/t = 747486.3388 values per ms
#
# numba_fast_sum
#     n   = 316227 values
#     t   = 0.403 ms
#     n/t = 783904.3133 values per ms
#
# numba_fast_sum
#     n   = 562341 values
#     t   = 0.863 ms
#     n/t = 651536.3226 values per ms
#
# numba_fast_sum
#     n   = 1000000 values
#     t   = 1.204 ms
#     n/t = 830357.8842 values per ms
#
# numba_fast_sum
#     n   = 1778279 values
#     t   = 3.215 ms
#     n/t = 553119.4401 values per ms
#
# numba_fast_sum
#     n   = 3162277 values
#     t   = 4.963 ms
#     n/t = 637106.2758 values per ms
#
# numba_fast_sum
#     n   = 5623413 values
#     t   = 7.548 ms
#     n/t = 745069.6257 values per ms
#
# numba_fast_sum
#     n   = 10000000 values
#     t   = 21.607 ms
#     n/t = 462819.4032 values per ms
#
#             function  n_values  t_milliseconds  values_per_ms
# 0           fast_sum         1           0.046        21.6920
# 1           fast_sum         3           0.006       476.1905
# 2           fast_sum         5           0.004      1282.0513
# 3           fast_sum        10           0.005      2173.9130
# 4           fast_sum        17           0.005      3207.5472
# 5           fast_sum        31           0.008      3974.3590
# 6           fast_sum        56           0.010      5600.0000
# 7           fast_sum       100           0.036      2747.2527
# 8           fast_sum       177           0.025      7137.0968
# 9           fast_sum       316           0.057      5553.6028
# 10          fast_sum       562           0.103      5461.6132
# 11          fast_sum      1000           0.152      6591.9578
# 12          fast_sum      1778           0.239      7426.9006
# 13          fast_sum      3162           0.396      7978.8039
# 14          fast_sum      5623           0.674      8343.9679
# 15          fast_sum     10000           1.163      8598.4523
# 16          fast_sum     17782           2.074      8571.7040
# 17          fast_sum     31622           3.890      8129.8848
# 18          fast_sum     56234           6.872      8182.9426
# 19          fast_sum    100000          12.919      7740.6570
# 20          fast_sum    177827          23.869      7450.1236
# 21          fast_sum    316227          42.155      7501.4945
# 22          fast_sum    562341          75.307      7467.2741
# 23          fast_sum   1000000         147.737      6768.7622
# 24          fast_sum   1778279         253.709      7009.1203
# 25          fast_sum   3162277         443.358      7132.5572
# 26          fast_sum   5623413        1036.672      5424.4883
# 27          fast_sum  10000000        1451.183      6890.9306
# 28   fast_native_sum         1           0.036        27.8552
# 29   fast_native_sum         3           0.007       434.7826
# 30   fast_native_sum         5           0.004      1219.5122
# 31   fast_native_sum        10           0.005      2222.2222
# 32   fast_native_sum        17           0.003      5483.8710
# 33   fast_native_sum        31           0.004      7750.0000
# 34   fast_native_sum        56           0.006     10000.0000
# 35   fast_native_sum       100           0.011      9090.9091
# 36   fast_native_sum       177           0.016     10925.9259
# 37   fast_native_sum       316           0.026     11969.6970
# 38   fast_native_sum       562           0.055     10236.7942
# 39   fast_native_sum      1000           0.097     10319.9174
# 40   fast_native_sum      1778           0.198      8979.7980
# 41   fast_native_sum      3162           0.325      9726.2381
# 42   fast_native_sum      5623           0.506     11119.2407
# 43   fast_native_sum     10000           0.715     13991.8847
# 44   fast_native_sum     17782           1.261     14099.2705
# 45   fast_native_sum     31622           2.292     13797.2861
# 46   fast_native_sum     56234           4.015     14004.2336
# 47   fast_native_sum    100000           8.122     12312.3900
# 48   fast_native_sum    177827          16.216     10966.2798
# 49   fast_native_sum    316227          26.870     11768.6442
# 50   fast_native_sum    562341          44.063     12762.2620
# 51   fast_native_sum   1000000          88.575     11289.8291
# 52   fast_native_sum   1778279         142.470     12481.7348
# 53   fast_native_sum   3162277         276.245     11447.3803
# 54   fast_native_sum   5623413         450.480     12483.1469
# 55   fast_native_sum  10000000         908.559     11006.4399
# 56    numpy_fast_sum         1           0.083        12.0627
# 57    numpy_fast_sum         3           0.026       116.2791
# 58    numpy_fast_sum         5           0.015       333.3333
# 59    numpy_fast_sum        10           0.016       641.0256
# 60    numpy_fast_sum        17           0.017       977.0115
# 61    numpy_fast_sum        31           0.011      2743.3628
# 62    numpy_fast_sum        56           0.015      3783.7838
# 63    numpy_fast_sum       100           0.022      4608.2949
# 64    numpy_fast_sum       177           0.033      5429.4479
# 65    numpy_fast_sum       316           0.008     42133.3333
# 66    numpy_fast_sum       562           0.017     33652.6946
# 67    numpy_fast_sum      1000           0.013     74626.8657
# 68    numpy_fast_sum      1778           0.010    177800.0000
# 69    numpy_fast_sum      3162           0.016    196397.5155
# 70    numpy_fast_sum      5623           0.031    182564.9351
# 71    numpy_fast_sum     10000           0.032    309597.5232
# 72    numpy_fast_sum     17782           0.423     42027.8894
# 73    numpy_fast_sum     31622           0.194    162748.3273
# 74    numpy_fast_sum     56234           0.585     96159.3707
# 75    numpy_fast_sum    100000           1.180     84745.7627
# 76    numpy_fast_sum    177827           0.410    434041.9819
# 77    numpy_fast_sum    316227           0.826    382748.7291
# 78    numpy_fast_sum    562341           0.974    577411.4385
# 79    numpy_fast_sum   1000000           2.012    497017.8926
# 80    numpy_fast_sum   1778279           3.892    456953.1812
# 81    numpy_fast_sum   3162277           6.491    487156.1937
# 82    numpy_fast_sum   5623413           9.852    570800.5644
# 83    numpy_fast_sum  10000000          17.227    580470.6456
# 84   pandas_fast_sum         1           0.296         3.3829
# 85   pandas_fast_sum         3           0.159        18.9036
# 86   pandas_fast_sum         5           0.150        33.2447
# 87   pandas_fast_sum        10           0.118        84.9618
# 88   pandas_fast_sum        17           0.198        85.6855
# 89   pandas_fast_sum        31           0.210       147.2684
# 90   pandas_fast_sum        56           0.139       401.7217
# 91   pandas_fast_sum       100           0.167       599.5204
# 92   pandas_fast_sum       177           0.216       820.9647
# 93   pandas_fast_sum       316           0.110      2877.9599
# 94   pandas_fast_sum       562           0.111      5053.9568
# 95   pandas_fast_sum      1000           0.333      3001.2005
# 96   pandas_fast_sum      1778           0.206      8639.4558
# 97   pandas_fast_sum      3162           0.136     23267.1082
# 98   pandas_fast_sum      5623           2.447      2297.6341
# 99   pandas_fast_sum     10000           0.164     61124.6944
# 100  pandas_fast_sum     17782           0.694     25604.0317
# 101  pandas_fast_sum     31622           0.801     39463.3720
# 102  pandas_fast_sum     56234           0.603     93241.5851
# 103  pandas_fast_sum    100000           1.649     60624.4316
# 104  pandas_fast_sum    177827           1.862     95487.8376
# 105  pandas_fast_sum    316227           3.689     85733.2249
# 106  pandas_fast_sum    562341           4.626    121558.3321
# 107  pandas_fast_sum   1000000          10.804     92554.0284
# 108  pandas_fast_sum   1778279          12.668    140375.6710
# 109  pandas_fast_sum   3162277          22.151    142758.7219
# 110  pandas_fast_sum   5623413          56.488     99550.0484
# 111  pandas_fast_sum  10000000          68.031    146991.3804
# 112   numba_fast_sum         1           0.035        28.6533
# 113   numba_fast_sum         3           0.031        98.0392
# 114   numba_fast_sum         5           0.027       187.9699
# 115   numba_fast_sum        10           0.010       970.8738
# 116   numba_fast_sum        17           0.017      1017.9641
# 117   numba_fast_sum        31           0.003      9393.9394
# 118   numba_fast_sum        56           0.016      3478.2609
# 119   numba_fast_sum       100           0.004     25641.0256
# 120   numba_fast_sum       177           0.004     42142.8571
# 121   numba_fast_sum       316           0.001    210666.6667
# 122   numba_fast_sum       562           0.002    312222.2223
# 123   numba_fast_sum      1000           0.002    454545.4544
# 124   numba_fast_sum      1778           0.005    348627.4510
# 125   numba_fast_sum      3162           0.005    632400.0002
# 126   numba_fast_sum      5623           0.009    624777.7779
# 127   numba_fast_sum     10000           0.014    714285.7143
# 128   numba_fast_sum     17782           0.022    819447.0046
# 129   numba_fast_sum     31622           0.038    834353.5620
# 130   numba_fast_sum     56234           0.073    773507.5653
# 131   numba_fast_sum    100000           0.122    821018.0624
# 132   numba_fast_sum    177827           0.238    747486.3388
# 133   numba_fast_sum    316227           0.403    783904.3133
# 134   numba_fast_sum    562341           0.863    651536.3226
# 135   numba_fast_sum   1000000           1.204    830357.8842
# 136   numba_fast_sum   1778279           3.215    553119.4401
# 137   numba_fast_sum   3162277           4.963    637106.2758
# 138   numba_fast_sum   5623413           7.548    745069.6257
# 139   numba_fast_sum  10000000          21.607    462819.4032
